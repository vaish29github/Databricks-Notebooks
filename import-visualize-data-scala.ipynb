// %%
val catalog = "adb_workspace_vaishnavi"
val schema = "default"
val volume = "volume"
val downloadUrl = "https://health.data.ny.gov/api/views/jxy9-yhdk/rows.csv"
val fileName = "baby_names.csv"
val tableName = "baby_names"
val pathVolume = s"/Volumes/${catalog}/${schema}/${volume}"
val pathTable = s"${catalog}.${schema}"
print(pathVolume) // Show the complete path
print(pathTable) // Show the complete path
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">/Volumes/adb_workspace_vaishnavi/default/volumeadb_workspace_vaishnavi.defaultcatalog: String = adb_workspace_vaishnavi
// schema: String = default
// volume: String = volume
// downloadUrl: String = https://health.data.ny.gov/api/views/jxy9-yhdk/rows.csv
// fileName: String = baby_names.csv
// tableName: String = baby_names
// pathVolume: String = /Volumes/adb_workspace_vaishnavi/default/volume
// pathTable: String = adb_workspace_vaishnavi.default
// </div>

// %%
dbutils.fs.cp(downloadUrl, s"/dbfs/${pathVolume}/${fileName}")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">res2: Boolean = true
// </div>

// %%
val df = spark.read
  .option("header", "true")
  .option("inferSchema", "true")
  .option("delimiter", ",")
  .csv(s"/dbfs/${pathVolume}/${fileName}")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">df: org.apache.spark.sql.DataFrame = [Year: int, First Name: string ... 3 more fields]
// </div>

// %%
display(df)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>First Name</th><th>County</th><th>Sex</th><th>Count</th></tr></thead><tbody><tr><td>2022</td><td>OLIVIA</td><td>Albany</td><td>F</td><td>16</td></tr><tr><td>2022</td><td>AMELIA</td><td>Albany</td><td>F</td><td>15</td></tr><tr><td>2022</td><td>AVERY</td><td>Albany</td><td>F</td><td>12</td></tr><tr><td>2022</td><td>EMMA</td><td>Albany</td><td>F</td><td>11</td></tr><tr><td>2022</td><td>CHARLOTTE</td><td>Albany</td><td>F</td><td>11</td></tr><tr><td>2022</td><td>CHLOE</td><td>Albany</td><td>F</td><td>11</td></tr><tr><td>2022</td><td>SOPHIA</td><td>Albany</td><td>F</td><td>8</td></tr><tr><td>2022</td><td>CORA</td><td>Albany</td><td>F</td><td>8</td></tr><tr><td>2022</td><td>MIA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>LUNA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>ELLA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>AURORA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>MAYA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>EMILIA</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>WILLOW</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>ELOISE</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>DELILAH</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>KINSLEY</td><td>Albany</td><td>F</td><td>7</td></tr><tr><td>2022</td><td>AVA</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>MADISON</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>HANNAH</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>VIOLET</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>NORA</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>ISLA</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>IVY</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>ALICE</td><td>Albany</td><td>F</td><td>6</td></tr><tr><td>2022</td><td>SOFIA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>EMILY</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>ABIGAIL</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>GRACE</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>NOVA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>MAEVE</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>AYLA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>LILLIAN</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>CLAIRE</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>ATHENA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>ARIELLA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>SADIE</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>AUBREY</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>AMARA</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>ADELINE</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>RYLEIGH</td><td>Albany</td><td>F</td><td>5</td></tr><tr><td>2022</td><td>LIAM</td><td>Albany</td><td>M</td><td>18</td></tr><tr><td>2022</td><td>ANTHONY</td><td>Albany</td><td>M</td><td>14</td></tr><tr><td>2022</td><td>LEO</td><td>Albany</td><td>M</td><td>12</td></tr><tr><td>2022</td><td>JACKSON</td><td>Albany</td><td>M</td><td>12</td></tr><tr><td>2022</td><td>NOAH</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>JOSEPH</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>OLIVER</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>JACK</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>THEODORE</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>OWEN</td><td>Albany</td><td>M</td><td>11</td></tr><tr><td>2022</td><td>CAMERON</td><td>Albany</td><td>M</td><td>11 ...
// Databricks visualization. Run in Databricks to view.

// %%
val dfRenamedColumn = df.withColumnRenamed("First Name", "First_Name")
// when modifying a DataFrame in Scala, you must assign it to a new variable
dfRenamedColumn.printSchema()
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">root
// -- Year: integer (nullable = true)
// -- First_Name: string (nullable = true)
// -- County: string (nullable = true)
// -- Sex: string (nullable = true)
// -- Count: integer (nullable = true)
//
// dfRenamedColumn: org.apache.spark.sql.DataFrame = [Year: int, First_Name: string ... 3 more fields]
// </div>

// %%
dfRenamedColumn.write.mode("overwrite").saveAsTable(s"${pathTable}.${tableName}")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout"></div>
